# %%
import pandas as pd

# %%
df = pd.read_csv("student_habits_performance.csv")

# %%
df.head(5)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
df.shape
# Out:
# (1000, 16)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna()
# Out:
#      student_id    age  gender  study_hours_per_day  social_media_hours  \
# 0         False  False   False                False               False
# 1         False  False   False                False               False
# 2         False  False   False                False               False
# 3         False  False   False                False               False
# 4         False  False   False                False               False
# ..          ...    ...     ...                  ...                 ...
# 995       False  False   False                False               False
# 996       False  False   False                False               False
# 997       False  False   False                False               False
# 998       False  False   False                False               False
# 999       False  False   False                False               False
#
#      netflix_hours  part_time_job  attendance_percentage  sleep_hours  \
# 0            False          False                  False        False
# 1            False          False                  False        False
# 2            False          False                  False        False
# 3            False          False                  False        False
# 4            False          False                  False        False
# ..             ...            ...                    ...          ...
# 995          False          False                  False        False
# 996          False          False                  False        False
# 997          False          False                  False        False
# 998          False          False                  False        False
# 999          False          False                  False        False
#
#      diet_quality  exercise_frequency  parental_education_level  \
# 0           False               False                     False
# 1           False               False                     False
# 2           False               False                     False
# 3           False               False                     False
# 4           False               False                     False
# ..            ...                 ...                       ...
# 995         False               False                     False
# 996         False               False                     False
# 997         False               False                     False
# 998         False               False                     False
# 999         False               False                     False
#
#      internet_quality  mental_health_rating  extracurricular_participation  \
# 0               False                 False                          False
# 1               False                 False                          False
# 2               False                 False                          False
# 3               False                 False                          False
# 4               False                 False                          False
# ..                ...                   ...                            ...
# 995             False                 False                          False
# 996             False                 False                          False
# 997             False                 False                          False
# 998             False                 False                          False
# 999             False                 False                          False
#
#      exam_score
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 995       False
# 996       False
# 997       False
# 998       False
# 999       False
#
# [909 rows x 16 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# min                56.000000     3.200000            0.000000
# 25%                77.500000     5.600000            1.000000
# 50%                84.200000     6.500000            3.000000
# 75%                90.700000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating  exam_score
# count            909.000000  909.000000
# mean               5.466447   69.558196
# std                2.857525   16.929436
# min                1.000000   18.400000
# 25%                3.000000   58.400000
# 50%                5.000000   70.400000
# 75%                8.000000   81.300000
# max               10.000000  100.000000

# %%
df.describe(include="object").columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
category_columns = ["gender", "part_time_job", "diet_quality", "parental_education_level", "internet_quality", "extracurricular_participation"]

# %%
for col in category_columns:
    print(f"ValueCount for column {col}: \n {df[col].value_counts()}")
# Out:
# ValueCount for column gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
# ValueCount for column part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
# ValueCount for column diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
# ValueCount for column parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
# ValueCount for column internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
# ValueCount for column extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20, edgecolor="black")
plt.tight_layout()
plt.show()

# %%
for col in category_columns:
    sns.countplot(data=df, x=col)
    plt.title("Distribution of {col}")
    plt.xticks(rotation = 45)
    plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("correlation matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for feature in num_features:
    sns.scatterplot(data = df, x=feature, y ="exam_score")
    plt.title(f"{feature} vs Exam score")
    plt.show()

# %%
for col in category_columns:
    sns.boxplot(data=df, x=col, y="exam_score")
    plt.title(f"Exam score by {col}")
    plt.xticks(rotation = 45)
    plt.show()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
features = ["study_hours_per_day", "attendance_percentage", "mental_health_rating", "sleep_hours", "part_time_job"]

# %%
target = "exam_score"

# %%
df_model = df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# 1            4.6            No       100.0
# 2            8.0            No        34.3
# 3            9.2            No        26.8
# 4            4.9            No        66.4
# ..           ...           ...         ...
# 995          7.5            No        76.1
# 996          6.8           Yes        65.9
# 997          6.5            No        64.4
# 998          7.6           Yes        69.7
# 999          7.1            No        74.9
#
# [909 rows x 6 columns]

# %%
le = LabelEncoder()

# %%
df_model["part_time_job"] = le.fit_transform(df_model["part_time_job"])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# 1            4.6              0       100.0
# 2            8.0              0        34.3
# 3            9.2              0        26.8
# 4            4.9              0        66.4
# ..           ...            ...         ...
# 995          7.5              0        76.1
# 996          6.8              1        65.9
# 997          6.5              0        64.4
# 998          7.6              1        69.7
# 999          7.1              0        74.9
#
# [909 rows x 6 columns]

# %%
X = df_model[features]

# %%
Y = df_model[target]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models = {
    "LinearRegression": { 
        "model": LinearRegression(), 
        "params": {} 
    },
    "DecisionTree": {
        "model": DecisionTreeRegressor(), 
        "params": {"max_depth": [3, 5, 10], "min_samples_split": [2, 5]}
    }, 
    "RandomForest": {
        "model": RandomForestRegressor(), 
        "params": {"n_estimators": [50, 100], "max_depth": [5, 10]}
    }
}

# %%
best_models = []

# %%
for name, config in models.items():
    print(f"Training {name}")
    
    grid = GridSearchCV(config["model"], config["params"], cv=5, scoring="neg_mean_squared_error")
    grid.fit(x_train, y_train)
    
    y_pred = grid.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    
    r2 = r2_score(y_test, y_pred)
    
    best_models.append({
        "model": name, 
        "params": grid.best_params_, 
        "rmse": rmse, 
        "r2": r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
results_df = pd.DataFrame(best_models)

# %%
results_df.sort_values(by="rmse")
# Out:
#               model                                    params      rmse  \
# 0  LinearRegression                                        {}  7.214060
# 2      RandomForest      {'max_depth': 5, 'n_estimators': 50}  7.996637
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  8.834287
#
#          r2
# 0  0.832197
# 2  0.793816
# 1  0.748358

# %%
import joblib
best_row = results_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model     LinearRegression
# params                  {}
# rmse               7.21406
# r2                0.832197
# Name: 0, dtype: object

# %%
best_model_name = best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"]

# %%
final_model.fit(X, Y)
# Out:
# LinearRegression()

# %%
final_model.predict(x_test)
# Out:
# array([ 73.37721953,  36.59323364,  46.52666247,  57.48846515,
#         65.54214455,  87.66820478, 100.79359858,  90.63779187,
#         81.85562938,  84.1404169 , 105.01596237,  73.66672527,
#         87.69201972,  54.12381522,  61.46176878,  54.8674567 ,
#         54.77778489,  84.17072978,  74.59529628,  44.89569851,
#         62.21932629,  85.31749649,  70.71589384,  85.77985132,
#         40.74930647,  79.36878895,  54.27941821,  82.07659987,
#         83.02517528,  75.11171869,  42.51199279,  63.46863323,
#         50.38351248,  72.64278476,  70.31885498,  59.86149389,
#         61.0234794 ,  74.41638106,  63.3153885 ,  45.2446473 ,
#         69.65327425,  42.15404292,  43.50243593,  67.17994482,
#         57.55284809, 102.05443373,  91.99423492,  51.22222835,
#         55.87543662,  76.53481528, 103.39848608,  52.60961208,
#         67.1142276 ,  52.76981731,  60.78719557,  70.5947591 ,
#         70.83486134,  96.07396925,  98.26310392,  82.72920286,
#        104.70803339,  86.05524853,  81.74485353,  57.44638498,
#         80.08715057,  51.45722985,  57.45595147, 102.15537878,
#         58.28779096,  84.28093066,  90.35284716,  83.47702877,
#         59.16887727,  57.82131369,  93.42130856,  64.51168013,
#         80.04701348,  54.2248526 ,  76.45016176,  69.09467311,
#         60.61304698,  53.07774872,  64.05479374,  69.99857536,
#         39.79507284,  71.57182983,  67.54393569,  94.26716699,
#         83.72423392,  59.41323383,  58.99100986,  40.0082463 ,
#         60.29610803,  61.81291391,  66.18579405,  57.0472934 ,
#         51.88362859,  53.20974487,  58.71341382,  64.21237739,
#         59.03104355,  69.31005922,  62.0019684 ,  54.1048007 ,
#         84.3068876 ,  81.11499936,  66.54212873,  72.4395309 ,
#        100.91762465,  90.68772396,  63.04843369,  63.72550851,
#         80.50391617,  77.28506823,  56.00371918,  53.89238682,
#         68.64068393,  74.89289694,  91.91388896,  59.88818359,
#         91.82549796,  85.9407813 ,  80.12262938,  73.63145597,
#         87.19369226,  74.55553431,  66.75598134,  79.75220639,
#         49.85660749,  86.04857975,  57.96780871,  54.1809859 ,
#         65.81297953,  54.84649087,  67.71027466,  60.95454931,
#         86.71282094,  80.85364674,  66.53984381,  58.02616961,
#         52.07971586,  94.97908174,  67.04794846,  50.09576014,
#         70.58123816,  67.77673736,  71.80449683,  80.37605908,
#         79.7157785 ,  72.22004207,  84.00104813,  96.72667692,
#         86.75373513,  44.85583341,  62.14063155,  72.17523691,
#         48.1785658 ,  56.25121079,  47.17047877,  55.89326092,
